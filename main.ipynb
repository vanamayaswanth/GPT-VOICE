# %%
# !pip install openai
# !pip install SpeechRecognition
# !pip install pyttsx3
# !pip install pipwin
# Out:
# Requirement already satisfied: openai in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (0.27.2)
# Requirement already satisfied: tqdm in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from openai) (4.62.3)
# Requirement already satisfied: aiohttp in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from openai) (3.8.1)
# Requirement already satisfied: requests>=2.20 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from openai) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.20->openai) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from aiohttp->openai) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from aiohttp->openai) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from aiohttp->openai) (1.7.2)
# Requirement already satisfied: colorama in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from tqdm->openai) (0.4.4)
# Requirement already satisfied: SpeechRecognition in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (3.10.0)
# Requirement already satisfied: requests>=2.26.0 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from SpeechRecognition) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: pyttsx3 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (2.90)
# Requirement already satisfied: pywin32 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from pyttsx3) (304)
# Requirement already satisfied: comtypes in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from pyttsx3) (1.1.14)
# Requirement already satisfied: pypiwin32 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from pyttsx3) (223)
# Collecting pipwin
#   Using cached pipwin-0.5.2.tar.gz (7.9 kB)
# Collecting docopt
#   Using cached docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: requests in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from pipwin) (2.28.1)
# Collecting pyprind
#   Using cached PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: six in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from pipwin) (1.16.0)
# Collecting beautifulsoup4>=4.9.0
#   Downloading beautifulsoup4-4.12.0-py3-none-any.whl (132 kB)
# Collecting js2py
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: packaging in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from pipwin) (21.0)
# Collecting pySmartDL>=1.3.1
#   Using cached pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Collecting pyjsparser>=2.5.1
#   Using cached pyjsparser-2.7.1.tar.gz (24 kB)
# Collecting tzlocal>=1.2
#   Downloading tzlocal-4.3-py3-none-any.whl (20 kB)
# Collecting backports.zoneinfo
#   Using cached backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from packaging->pipwin) (3.0.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests->pipwin) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests->pipwin) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests->pipwin) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\yaswanth\anaconda3\envs\obj\lib\site-packages (from requests->pipwin) (1.26.12)
# Building wheels for collected packages: pipwin, docopt, pyjsparser
#   Building wheel for pipwin (setup.py): started
#   Building wheel for pipwin (setup.py): finished with status 'done'
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8790 sha256=5dea5781a8b10c403883961de5a665bf695e469c49659a362e4b2047d1f018c3
#   Stored in directory: c:\users\yaswanth\appdata\local\pip\cache\wheels\f4\a8\76\372879a40d2d4dd7de23efd867ed37112687429b8d0dda4545
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13724 sha256=7bc3424942cbca68a0e2b675e4eb26c39638fc874e4e4b286692b5b644090582
#   Stored in directory: c:\users\yaswanth\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
#   Building wheel for pyjsparser (setup.py): started
#   Building wheel for pyjsparser (setup.py): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26001 sha256=556708d7643944d0e9fc9d869840ec8ea86f2efd6728ab47348b1bad670bed72
#   Stored in directory: c:\users\yaswanth\appdata\local\pip\cache\wheels\d5\88\34\ccb5bb40eb3178a134eb293e6c363928c5bcfba0b91031db76
# Successfully built pipwin docopt pyjsparser
# Installing collected packages: tzdata, backports.zoneinfo, pytz-deprecation-shim, tzlocal, soupsieve, pyjsparser, pySmartDL, pyprind, js2py, docopt, beautifulsoup4, pipwin
# Successfully installed backports.zoneinfo-0.2.1 beautifulsoup4-4.12.0 docopt-0.6.2 js2py-0.74 pipwin-0.5.2 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 pytz-deprecation-shim-0.1.0.post0 soupsieve-2.4 tzdata-2022.7 tzlocal-4.3

# %%
# !pipwin install pyaudio
# Out:
# Package `pyaudio` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/archived/PyAudio-0.2.11-cp38-cp38-win_amd64.whl
# PyAudio-0.2.11-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 111 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 8 kB / 111 kB @ 6 kB/s [#-----------------] [7.2%, 0s left]   [*] 8 kB / 111 kB @ 6 kB/s [#-----------------] [7.2%, 0s left]   [*] 40 kB / 111 kB @ 27 kB/s [######------------] [36.0%, 0s left]  [*] 40 kB / 111 kB @ 25 kB/s [######------------] [36.0%, 0s left]  [*] 56 kB / 111 kB @ 33 kB/s [#########---------] [50.4%, 0s left]  [*] 56 kB / 111 kB @ 31 kB/s [#########---------] [50.4%, 0s left]  [*] 56 kB / 111 kB @ 29 kB/s [#########---------] [50.4%, 0s left]  [*] 111 kB / 111 kB @ 29 kB/s [##################] [100%, 0s left]
# Processing c:\users\yaswanth\pipwin\pyaudio-0.2.11-cp38-cp38-win_amd64.whl
# Installing collected packages: PyAudio
# Successfully installed PyAudio-0.2.11

# %%
import openai

import speech_recognition as sr
import pyttsx3
import time 


# Initialize OpenAI API
openai.api_key = "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"
# Initialize the text to speech engine 
engine=pyttsx3.init()


def transcribe_audio_to_test(filename):
    recogizer=sr.Recognizer()
    with sr.AudioFile(filename)as source:
        audio=recogizer.record(source) 
    try:
        return recogizer.recognize_google(audio)
    except:
        print("skipping unkown error")

def generate_response(prompt):
    response= openai.completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=4000,
        n=1,
        stop=None,
        temperature=0.5,
    )
    return response ["Choices"][0]["text"]
def speak_text(text):
    engine.say(text)
    engine.runAndWait()

def main():
    while True:
        #Waith for user say "genius"
        print("Say 'one' to start recording your question")
        with sr.Microphone() as source:
            recognizer=sr.Recognizer()
            audio=recognizer.listen(source)
            try:
                transcription = recognizer.recognize_google(audio)
                if transcription.lower()=="one":
                    #record audio
                    filename ="input.wav"
                    print("Say your question")
                    with sr.Microphone() as source:
                        recognizer=sr.recognize()
                        source.pause_threshold=1
                        audio=recognizer.listen(source,phrase_time_limit=None,timeout=None)
                        with open(filename,"wb")as f:
                            f.write(audio.get_wav_data())
                            
                            
                        
                        
                    #transcript audio to test 
                    text=transcribe_audio_to_test(filename)
                    if text:
                        print(f"yuo said {text}")
                        
                        #Generate the response
                        response = generate_response(text)
                        print(f"chat gpt 3 say {response}")
                            
                        #read resopnse using GPT3
                        speak_text(response)
            except Exception as e:
                
                print("An error ocurred : {}".format(e))
if __name__=="__main__":
    main()
# Out:
# Say 'one' to start recording your question
# Say your question
# An error ocurred : module 'speech_recognition' has no attribute 'recognize'
# Say 'one' to start recording your question
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22840\1493134858.py in <module>
#      73                 print("An error ocurred : {}".format(e))
#      74 if __name__=="__main__":
# ---> 75     main()
#      76
#
# ~\AppData\Local\Temp\ipykernel_22840\1493134858.py in main()
#      41         with sr.Microphone() as source:
#      42             recognizer=sr.Recognizer()
# ---> 43             audio=recognizer.listen(source)
#      44             try:
#      45                 transcription = recognizer.recognize_google(audio)
#
# d:\Users\YASWANTH\anaconda3\envs\obj\lib\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     489                         raise WaitTimeoutError("listening timed out while waiting for phrase to start")
#     490
# --> 491                     buffer = source.stream.read(source.CHUNK)
#     492                     if len(buffer) == 0: break  # reached end of the stream
#     493                     frames.append(buffer)
#
# d:\Users\YASWANTH\anaconda3\envs\obj\lib\site-packages\speech_recognition\__init__.py in read(self, size)
#     197
#     198         def read(self, size):
# --> 199             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     200
#     201         def close(self):
#
# d:\Users\YASWANTH\anaconda3\envs\obj\lib\site-packages\pyaudio.py in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:
